# %% [markdown]
# ### Day 1: Introduction to Python for Data Science
#
# Welcome to Day 1! In today’s session, we’ll cover some essential concepts and techniques you’ll use in Python for data science.
#
# **Overview of the Topics for Today:**
# 1. Introduction to Python for Data Science.
# 2. Data manipulation with Pandas:
#    - Data cleaning and transformation.
#    - Grouping, merging, and aggregating data.
# 3. Introduction to NumPy:
#    - Array creation and manipulation.
#    - Vectorized operations for efficient computation.
#
# Let’s get started!

# %% [markdown]
# ### Install the libraries using pip if not already installed

# %%
# !pip install pandas numpy matplotlib
# This command uses `!pip install` to install the necessary libraries
# for data manipulation (`pandas`), numerical calculations (`numpy`)
# Out:
# Requirement already satisfied: pandas in c:\users\sriva\appdata\local\programs\python\python310\lib\site-packages (2.2.0)
# Requirement already satisfied: numpy in c:\users\sriva\appdata\local\programs\python\python310\lib\site-packages (1.24.3)
# Requirement already satisfied: matplotlib in c:\users\sriva\appdata\local\programs\python\python310\lib\site-packages (3.8.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sriva\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sriva\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sriva\appdata\local\programs\python\python310\lib\site-packages (from pandas) (2023.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\sriva\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\sriva\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\sriva\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (4.47.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\sriva\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in c:\users\sriva\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\sriva\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (10.2.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\sriva\appdata\local\programs\python\python310\lib\site-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: six>=1.5 in c:\users\sriva\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 24.2 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Import Libraries
# In this cell, we will import the required libraries. The following libraries are crucial for our project:
# - `pandas`: for data manipulation.
# - `numpy`: for numerical operations.

# %%
import pandas as pd
import numpy as np
import time
#import matplotlib.pyplot as plt

# %% [markdown]
# ### Data Manipulation with Pandas: Data Cleaning and Transformation
#
# One of the first steps in data science is to clean and transform your data. We will use **Pandas** for that purpose, which provides robust tools for data manipulation.
#
# **Data Cleaning Tasks:**
# - Handling missing values.
# - Converting data types.
# - Removing duplicates.
# - Filtering data.

# %% [markdown]
# ### Data set link : <br>
# - https://www.kaggle.com/datasets/mahendran1/icc-cricket?resource=download

# %%
# Sample DataFrame
df = pd.read_csv("Batting\\ODI data.csv")
df.head()
# Out:
#    Unnamed: 0                       Player       Span  Mat Inns  NO   Runs  \
# 0           0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426
# 1           1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234
# 2           2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704
# 3           3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430
# 4           4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650
#
#      HS    Ave     BF     SR 100  50   0  Unnamed: 13
# 0  200*  44.83  21367  86.23  49  96  20          NaN
# 1   169  41.98  18048  78.86  25  93  15          NaN
# 2   164  42.03  17046  80.39  30  82  20          NaN
# 3   189  32.36  14725   91.2  28  68  34          NaN
# 4   144  33.37  16020  78.96  19  77  28          NaN

# %% [markdown]
# ### Find different exsting columns

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS',
#        'Ave', 'BF', 'SR', '100', '50', '0', 'Unnamed: 13'],
#       dtype='object')

# %%
# Drop a single column by name
df = df.drop(['Unnamed: 0','Unnamed: 13'], axis=1)

# %%
df.head()
# Out:
#                         Player       Span  Mat Inns  NO   Runs    HS    Ave  \
# 0         SR Tendulkar (INDIA)  1989-2012  463  452  41  18426  200*  44.83
# 1  KC Sangakkara (Asia/ICC/SL)  2000-2015  404  380  41  14234   169  41.98
# 2         RT Ponting (AUS/ICC)  1995-2012  375  365  39  13704   164  42.03
# 3      ST Jayasuriya (Asia/SL)  1989-2011  445  433  18  13430   189  32.36
# 4   DPMD Jayawardene (Asia/SL)  1998-2015  448  418  39  12650   144  33.37
#
#       BF     SR 100  50   0
# 0  21367  86.23  49  96  20
# 1  18048  78.86  25  93  15
# 2  17046  80.39  30  82  20
# 3  14725   91.2  28  68  34
# 4  16020  78.96  19  77  28

# %%
df.isnull().sum()
# Out:
# Player    0
# Span      0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Ave       0
# BF        0
# SR        0
# 100       0
# 50        0
# 0         0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Player  2500 non-null   object
#  1   Span    2500 non-null   object
#  2   Mat     2500 non-null   int64
#  3   Inns    2500 non-null   object
#  4   NO      2500 non-null   object
#  5   Runs    2500 non-null   object
#  6   HS      2500 non-null   object
#  7   Ave     2500 non-null   object
#  8   BF      2500 non-null   object
#  9   SR      2500 non-null   object
#  10  100     2500 non-null   object
#  11  50      2500 non-null   object
#  12  0       2500 non-null   object
# dtypes: int64(1), object(12)
# memory usage: 254.0+ KB

# %% [markdown]
# ### **Overview of the DataFrame**
# - **Type**:
#   `<class 'pandas.core.frame.DataFrame'>` indicates that the object is a Pandas DataFrame.
#
# - **Rows**:
#   `RangeIndex: 2500 entries, 0 to 2499` specifies the DataFrame has **2,500 rows**, indexed from `0` to `2499`.
#
# - **Columns**:
#   `Data columns (total 13 columns)` means the DataFrame contains **13 columns**.
#
# ---
#
# ### **Column Information**
# For each column, the following details are provided:
#
# 1. **Column Name**:
#    The name of each column, e.g., `Player`, `Span`, `Mat`, etc.
#
# 2. **Non-Null Count**:
#    The number of **non-null (non-missing)** values in each column.
#    - Here, every column has **2500 non-null values**, meaning there are no missing values in any column.
#
# 3. **Data Type (Dtype)**:
#    - The type of data stored in each column.
#      For example:
#      - `object`: Represents strings or mixed types.
#      - `int64`: Represents integers.
#
# ---
#
# ### **Per-Column Details**
# | **Column** | **Description** | **Dtype** |
# |------------|-----------------|-----------|
# | `Player`   | contains player names. | `object` (text) |
# | `Span`     | represents the player's career span (e.g., 2000–2010). | `object` (text) |
# | `Mat`      | Total matches played by each player. | `int64` (integer) |
# | `Inns`     | Number of innings played. | `object` (text, possibly due to special cases like `'-'`) |
# | `NO`       | Not-outs (number of times the player remained not out). | `object` (text) |
# | `Runs`     | Total runs scored by the player. | `object`  |
# | `HS`       | Highest score made by the player. | `object` |
# | `Ave`      | Batting average. | `object` (text, possibly due to missing or invalid values) |
# | `BF`       | Balls faced by the player. | `object` (text, likely contains invalid or missing values) |
# | `SR`       | Strike rate. | `object` (text, possibly due to missing/invalid entries) |
# | `100`      | Number of centuries. | `object` (text, possibly contains special values) |
# | `50`       | Number of half-centuries. | `object` (text, possibly contains special values) |
# | `0`        | Number of ducks (scores of zero). | `object` (text) |
#
# ---
#
# ### **Data Type Summary**
# - `dtypes: int64(1), object(12)`:
#   - `int64(1)`: There is **1 column** (`Mat`) with numeric data.
#   - `object(12)`: There are **12 columns** with text or mixed data types.
#
# ---
#
# ### **Memory Usage**
# - `memory usage: 254.0+ KB`: The DataFrame uses approximately **254 KB** of memory.

# %%
df.describe()
# Out:
#                Mat
# count  2500.000000
# mean     37.161600
# std      58.885075
# min       1.000000
# 25%       4.000000
# 50%      13.000000
# 75%      43.000000
# max     463.000000

# %%
df.columns
# Out:
# Index(['Player', 'Span', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Ave', 'BF', 'SR',
#        '100', '50', '0'],
#       dtype='object')

# %%
df = df.replace('-', 0)

# %%
df["Player"].value_counts()
# Out:
# Player
# Raqibul Hasan (BDESH)     2
# SR Tendulkar (INDIA)      1
# PJ Martin (ENG)           1
# A Shahzad (ENG)           1
# SN Thakur (INDIA)         1
#                          ..
# Aaqib Javed (PAK)         1
# Shamsur Rahman (BDESH)    1
# CA Soper (PNG)            1
# JM Vince (ENG)            1
# GR Beard (AUS)            1
# Name: count, Length: 2499, dtype: int64

# %%
df = df.drop_duplicates()

# %%
df.shape
# Out:
# (2500, 13)

# %%
# why duplicate player....

# %%
split_data = df['Player'].str.split('(', expand=True)


data = pd.DataFrame({
    'Player_Name': split_data[0].str.strip(),
    'Team': split_data[1].str.strip(')')
})

# %%
data
# Out:
#            Player_Name         Team
# 0         SR Tendulkar        INDIA
# 1        KC Sangakkara  Asia/ICC/SL
# 2           RT Ponting      AUS/ICC
# 3        ST Jayasuriya      Asia/SL
# 4     DPMD Jayawardene      Asia/SL
# ...                ...          ...
# 2495         ZS Ansari          ENG
# 2496      Ariful Haque        BDESH
# 2497      Ashfaq Ahmed          PAK
# 2498         MD Bailey           NZ
# 2499          GR Beard          AUS
#
# [2500 rows x 2 columns]

# %%
data["Team"].value_counts()
# Out:
# Team
# ENG               239
# PAK               213
# AUS               212
# INDIA             208
# WI                188
# NZ                186
# SL                178
# ZIM               132
# BDESH             126
# SA                103
# CAN                83
# UAE                81
# SCOT               68
# NL                 64
# IRE                54
# KENYA              46
# AFG                44
# HKG                40
# BMUDA              35
# USA                27
# NAM                26
# PNG                23
# NEPAL              19
# Afr/SA             15
# EAf                13
# OMAN               13
# Asia/INDIA          7
# Asia/SL             5
# AUS/ICC             5
# Afr/ZIM             4
# Asia/PAK            4
# USA/WI              3
# Afr/KENYA           3
# Asia/BDESH          3
# ENG/ICC             3
# ENG/IRE             3
# ICC/NZ              3
# Asia/ICC/PAK        2
# Asia/ICC/SL         2
# Afr/ICC/SA          2
# ICC/WI              2
# Asia/ICC/INDIA      2
# ICC/SA              1
# SA/USA              1
# NL/SA               1
# HKG/NZ              1
# AUS/NZ              1
# 3)                  1
# AUS/SA              1
# ENG/SCOT            1
# CAN/WI              1
# ENG/PNG             1
# 1)                  1
# Name: count, dtype: int64

# %%
data.columns
# Out:
# Index(['Player_Name', 'Team'], dtype='object')

# %%
df["Span"].value_counts()
# Out:
# Span
# 2019-2019    101
# 2018-2019     37
# 2017-2019     35
# 2003-2003     33
# 2018-2018     32
#             ...
# 1980-1993      1
# 1995-2002      1
# 1987-1989      1
# 1974-1982      1
# 1990-1993      1
# Name: count, Length: 566, dtype: int64

# %%
# Perform the split with safety
split_columns = df['Span'].str.split('-', expand=True)

# Assign columns dynamically based on split result
data['Debute_Year'] = split_columns[0]
# Convert 'Player' column to string
data['Debute_Year'] = data['Debute_Year'].astype(int)

data['Retirment_Year'] = split_columns[1]
data['Retirment_Year'] = data['Retirment_Year'].astype(int)
data
# Out:
#            Player_Name         Team  Debute_Year  Retirment_Year
# 0         SR Tendulkar        INDIA         1989            2012
# 1        KC Sangakkara  Asia/ICC/SL         2000            2015
# 2           RT Ponting      AUS/ICC         1995            2012
# 3        ST Jayasuriya      Asia/SL         1989            2011
# 4     DPMD Jayawardene      Asia/SL         1998            2015
# ...                ...          ...          ...             ...
# 2495         ZS Ansari          ENG         2015            2015
# 2496      Ariful Haque        BDESH         2018            2018
# 2497      Ashfaq Ahmed          PAK         1994            1994
# 2498         MD Bailey           NZ         1998            1998
# 2499          GR Beard          AUS         1981            1981
#
# [2500 rows x 4 columns]

# %% [markdown]
# ### Did Virat Kholi retire in ODIS

# %%
data["Span"] = data["Retirment_Year"] - data["Debute_Year"]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Player_Name     2500 non-null   object
#  1   Team            2500 non-null   object
#  2   Debute_Year     2500 non-null   int32
#  3   Retirment_Year  2500 non-null   int32
#  4   Span            2500 non-null   int32
# dtypes: int32(3), object(2)
# memory usage: 68.5+ KB

# %%
print(df["Inns"].info())
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2500 entries, 0 to 2499
# Series name: Inns
# Non-Null Count  Dtype
# --------------  -----
# 2500 non-null   object
# dtypes: object(1)
# memory usage: 19.7+ KB
# None

# %%
data['Inns'] = df['Inns'].astype(int)

# %%
# Create the 'Not_Out' column: 1 if '*' is in 'HS', else 0
data['HS_Not_Out'] = df['HS'].apply(lambda x: 1 if '*' in str(x) else 0)

# Optionally, clean the 'HS' column to remove '*'
data['HS'] = df['HS'].apply(lambda x: str(x).replace('*', '').strip())

# %%
data
# Out:
#            Player_Name         Team  Debute_Year  Retirment_Year  Span  Inns  \
# 0         SR Tendulkar        INDIA         1989            2012    23   452
# 1        KC Sangakkara  Asia/ICC/SL         2000            2015    15   380
# 2           RT Ponting      AUS/ICC         1995            2012    17   365
# 3        ST Jayasuriya      Asia/SL         1989            2011    22   433
# 4     DPMD Jayawardene      Asia/SL         1998            2015    17   418
# ...                ...          ...          ...             ...   ...   ...
# 2495         ZS Ansari          ENG         2015            2015     0     0
# 2496      Ariful Haque        BDESH         2018            2018     0     0
# 2497      Ashfaq Ahmed          PAK         1994            1994     0     0
# 2498         MD Bailey           NZ         1998            1998     0     0
# 2499          GR Beard          AUS         1981            1981     0     0
#
#       HS_Not_Out   HS
# 0              1  200
# 1              0  169
# 2              0  164
# 3              0  189
# 4              0  144
# ...          ...  ...
# 2495           0    0
# 2496           0    0
# 2497           0    0
# 2498           0    0
# 2499           0    0
#
# [2500 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2500 entries, 0 to 2499
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Player_Name     2500 non-null   object
#  1   Team            2500 non-null   object
#  2   Debute_Year     2500 non-null   int32
#  3   Retirment_Year  2500 non-null   int32
#  4   Span            2500 non-null   int32
#  5   Inns            2500 non-null   int32
#  6   HS_Not_Out      2500 non-null   int64
#  7   HS              2500 non-null   object
# dtypes: int32(4), int64(1), object(3)
# memory usage: 117.3+ KB

# %%
df["NO"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 2500 entries, 0 to 2499
# Series name: NO
# Non-Null Count  Dtype
# --------------  -----
# 2500 non-null   object
# dtypes: object(1)
# memory usage: 19.7+ KB

# %% [markdown]
# ### Creating new columns for better readability

# %%
data["NotOuts"] = df["NO"].astype("int")
data["Average"] = df["Ave"].astype("float")
data["BallsFaced"] = df["BF"].astype("int")
data["StrikeRate"] = df["SR"].astype("float")
data["100s"] = df["100"].astype("int")
data["50s"] = df["50"].astype("int")
data["0s"] = df["0"].astype("int")
data["Runs"] = df["Runs"].astype("int")

# %%
data.head()
# Out:
#         Player_Name         Team  Debute_Year  Retirment_Year  Span  Inns  \
# 0      SR Tendulkar        INDIA         1989            2012    23   452
# 1     KC Sangakkara  Asia/ICC/SL         2000            2015    15   380
# 2        RT Ponting      AUS/ICC         1995            2012    17   365
# 3     ST Jayasuriya      Asia/SL         1989            2011    22   433
# 4  DPMD Jayawardene      Asia/SL         1998            2015    17   418
#
#    HS_Not_Out   HS  NotOuts  Average  BallsFaced  StrikeRate  100s  50s  0s  \
# 0           1  200       41    44.83       21367       86.23    49   96  20
# 1           0  169       41    41.98       18048       78.86    25   93  15
# 2           0  164       39    42.03       17046       80.39    30   82  20
# 3           0  189       18    32.36       14725       91.20    28   68  34
# 4           0  144       39    33.37       16020       78.96    19   77  28
#
#     Runs
# 0  18426
# 1  14234
# 2  13704
# 3  13430
# 4  12650

# %%
# Separate numerical and categorical columns
numerical_columns = data.select_dtypes(include=['int32', 'float64']).columns
categorical_columns = data.select_dtypes(include=['object', 'bool']).columns

# Display results
print("Numerical Columns:", numerical_columns.tolist())
# Out:
# Numerical Columns: ['Debute_Year', 'Retirment_Year', 'Span', 'Inns', 'NotOuts', 'Average', 'BallsFaced', 'StrikeRate', '100s', '50s', '0s', 'Runs']

# %%
print("Categorical Columns:", categorical_columns.tolist())
# Out:
# Categorical Columns: ['Player_Name', 'Team', 'HS']

# %%
data
# Out:
#            Player_Name         Team  Debute_Year  Retirment_Year  Span  Inns  \
# 0         SR Tendulkar        INDIA         1989            2012    23   452
# 1        KC Sangakkara  Asia/ICC/SL         2000            2015    15   380
# 2           RT Ponting      AUS/ICC         1995            2012    17   365
# 3        ST Jayasuriya      Asia/SL         1989            2011    22   433
# 4     DPMD Jayawardene      Asia/SL         1998            2015    17   418
# ...                ...          ...          ...             ...   ...   ...
# 2495         ZS Ansari          ENG         2015            2015     0     0
# 2496      Ariful Haque        BDESH         2018            2018     0     0
# 2497      Ashfaq Ahmed          PAK         1994            1994     0     0
# 2498         MD Bailey           NZ         1998            1998     0     0
# 2499          GR Beard          AUS         1981            1981     0     0
#
#       HS_Not_Out   HS  NotOuts  Average  BallsFaced  StrikeRate  100s  50s  \
# 0              1  200       41    44.83       21367       86.23    49   96
# 1              0  169       41    41.98       18048       78.86    25   93
# 2              0  164       39    42.03       17046       80.39    30   82
# 3              0  189       18    32.36       14725       91.20    28   68
# 4              0  144       39    33.37       16020       78.96    19   77
# ...          ...  ...      ...      ...         ...         ...   ...  ...
# 2495           0    0        0     0.00           0        0.00     0    0
# 2496           0    0        0     0.00           0        0.00     0    0
# 2497           0    0        0     0.00           0        0.00     0    0
# 2498           0    0        0     0.00           0        0.00     0    0
# 2499           0    0        0     0.00           0        0.00     0    0
#
#       0s   Runs
# 0     20  18426
# 1     15  14234
# 2     20  13704
# 3     34  13430
# 4     28  12650
# ...   ..    ...
# 2495   0      0
# 2496   0      0
# 2497   0      0
# 2498   0      0
# 2499   0      0
#
# [2500 rows x 16 columns]

# %% [markdown]
# ### Average Above 40 from India

# %%
data[(data["Average"] > 40) &  (data["Team"] == "INDIA")]
# Out:
#        Player_Name   Team  Debute_Year  Retirment_Year  Span  Inns  \
# 0     SR Tendulkar  INDIA         1989            2012    23   452
# 6          V Kohli  INDIA         2008            2019    11   233
# 19       RG Sharma  INDIA         2007            2019    12   214
# 73        S Dhawan  INDIA         2010            2019     9   131
# 268      AT Rayudu  INDIA         2013            2019     6    50
# 309      KM Jadhav  INDIA         2014            2019     5    50
# 420       KL Rahul  INDIA         2016            2019     3    25
# 626        SS Iyer  INDIA         2017            2019     2    10
# 1186      GK Khoda  INDIA         1998            1998     0     2
# 1607     AV Mankad  INDIA         1974            1974     0     1
#
#       HS_Not_Out   HS  NotOuts  Average  BallsFaced  StrikeRate  100s  50s  \
# 0              1  200       41    44.83       21367       86.23    49   96
# 6              0  183       39    59.84       12445       93.28    43   55
# 19             0  264       32    49.14       10063       88.88    28   43
# 73             0  143        7    44.50        5869       94.01    17   27
# 268            1  124       14    47.05        2143       79.04     3   10
# 309            0  120       18    42.31        1325      102.18     2    6
# 420            0  111        4    42.33        1098       80.96     3    5
# 626            0   88        0    47.60         454      104.84     0    6
# 1186           0   89        0    57.50         185       62.16     0    1
# 1607           0   44        0    44.00          61       72.13     0    0
#
#       0s   Runs
# 0     20  18426
# 6     13  11609
# 19    13   8944
# 73     5   5518
# 268    3   1694
# 309    2   1354
# 420    2    889
# 626    0    476
# 1186   0    115
# 1607   0     44

# %%
data["Team"].value_counts()
# Out:
# Team
# ENG               239
# PAK               213
# AUS               212
# INDIA             208
# WI                188
# NZ                186
# SL                178
# ZIM               132
# BDESH             126
# SA                103
# CAN                83
# UAE                81
# SCOT               68
# NL                 64
# IRE                54
# KENYA              46
# AFG                44
# HKG                40
# BMUDA              35
# USA                27
# NAM                26
# PNG                23
# NEPAL              19
# Afr/SA             15
# EAf                13
# OMAN               13
# Asia/INDIA          7
# Asia/SL             5
# AUS/ICC             5
# Afr/ZIM             4
# Asia/PAK            4
# USA/WI              3
# Afr/KENYA           3
# Asia/BDESH          3
# ENG/ICC             3
# ENG/IRE             3
# ICC/NZ              3
# Asia/ICC/PAK        2
# Asia/ICC/SL         2
# Afr/ICC/SA          2
# ICC/WI              2
# Asia/ICC/INDIA      2
# ICC/SA              1
# SA/USA              1
# NL/SA               1
# HKG/NZ              1
# AUS/NZ              1
# 3)                  1
# AUS/SA              1
# ENG/SCOT            1
# CAN/WI              1
# ENG/PNG             1
# 1)                  1
# Name: count, dtype: int64

# %%
# Replace specific patterns
data.Team = data.Team.str.replace('Afr/', '', regex=False)
data.Team= data.Team.str.replace('ASIA/', '', regex=False)
data.Team= data.Team.str.replace('Asia/', '', regex=False)
data.Team = data.Team.str.replace('ICC/', '', regex=False)
data.Team = data.Team.str.replace('/ICC', '', regex=False)

# %%
data["Team"].value_counts()
# Out:
# Team
# ENG         242
# PAK         219
# INDIA       217
# AUS         217
# WI          190
# NZ          189
# SL          185
# ZIM         136
# BDESH       129
# SA          121
# CAN          83
# UAE          81
# SCOT         68
# NL           64
# IRE          54
# KENYA        49
# AFG          44
# HKG          40
# BMUDA        35
# USA          27
# NAM          26
# PNG          23
# NEPAL        19
# OMAN         13
# EAf          13
# USA/WI        3
# ENG/IRE       3
# NL/SA         1
# HKG/NZ        1
# 3)            1
# SA/USA        1
# AUS/NZ        1
# ENG/SCOT      1
# CAN/WI        1
# ENG/PNG       1
# AUS/SA        1
# 1)            1
# Name: count, dtype: int64

# %%
data
# Out:
#            Player_Name   Team  Debute_Year  Retirment_Year  Span  Inns  \
# 0         SR Tendulkar  INDIA         1989            2012    23   452
# 1        KC Sangakkara     SL         2000            2015    15   380
# 2           RT Ponting    AUS         1995            2012    17   365
# 3        ST Jayasuriya     SL         1989            2011    22   433
# 4     DPMD Jayawardene     SL         1998            2015    17   418
# ...                ...    ...          ...             ...   ...   ...
# 2495         ZS Ansari    ENG         2015            2015     0     0
# 2496      Ariful Haque  BDESH         2018            2018     0     0
# 2497      Ashfaq Ahmed    PAK         1994            1994     0     0
# 2498         MD Bailey     NZ         1998            1998     0     0
# 2499          GR Beard    AUS         1981            1981     0     0
#
#       HS_Not_Out   HS  NotOuts  Average  BallsFaced  StrikeRate  100s  50s  \
# 0              1  200       41    44.83       21367       86.23    49   96
# 1              0  169       41    41.98       18048       78.86    25   93
# 2              0  164       39    42.03       17046       80.39    30   82
# 3              0  189       18    32.36       14725       91.20    28   68
# 4              0  144       39    33.37       16020       78.96    19   77
# ...          ...  ...      ...      ...         ...         ...   ...  ...
# 2495           0    0        0     0.00           0        0.00     0    0
# 2496           0    0        0     0.00           0        0.00     0    0
# 2497           0    0        0     0.00           0        0.00     0    0
# 2498           0    0        0     0.00           0        0.00     0    0
# 2499           0    0        0     0.00           0        0.00     0    0
#
#       0s   Runs
# 0     20  18426
# 1     15  14234
# 2     20  13704
# 3     34  13430
# 4     28  12650
# ...   ..    ...
# 2495   0      0
# 2496   0      0
# 2497   0      0
# 2498   0      0
# 2499   0      0
#
# [2500 rows x 16 columns]

# %%
# Group by 'Team' and find the earliest debut year for each country
earliest_debut = data.groupby('Team')['Debute_Year'].min()

# Merge the result back to the original DataFrame to get player details
first_players = data[data.apply(lambda x: x['Debute_Year'] == earliest_debut[x['Team']], axis=1)]
first_players
# Out:
#           Player_Name     Team  Debute_Year  Retirment_Year  Span  Inns  \
# 37         EJG Morgan  ENG/IRE         2006            2019    13   217
# 108   WTS Porterfield      IRE         2006            2019    13   133
# 131        KJ O'Brien      IRE         2006            2019    13   130
# 133         SO Tikolo    KENYA         1996            2014    18   130
# 138        KC Wessels   AUS/SA         1983            1994    11   105
# ...               ...      ...          ...             ...   ...   ...
# 2440         LR Gibbs       WI         1973            1975     2     1
# 2448      Kaleemullah     OMAN         2019            2019     0     1
# 2462     Nasir Hameed      HKG         2004            2004     0     1
# 2484        GS Sobers       WI         1973            1973     0     1
# 2487        R Walters      NAM         2003            2003     0     2
#
#       HS_Not_Out   HS  NotOuts  Average  BallsFaced  StrikeRate  100s  50s  \
# 37             0  148       32    39.71        8053       91.24    13   46
# 108            0  139        3    31.05        5818       69.38    11   17
# 131            0  142       17    30.88        3922       88.98     2   18
# 133            0  111       12    29.05        4524       75.77     3   24
# 138            0  107        7    34.35        6088       55.30     1   26
# ...          ...  ...      ...      ...         ...         ...   ...  ...
# 2440           1    0        1     0.00           0        0.00     0    0
# 2448           0    0        0     0.00           2        0.00     0    0
# 2462           0    0        0     0.00           1        0.00     0    0
# 2484           0    0        0     0.00           6        0.00     0    0
# 2487           0    0        0     0.00           5        0.00     0    0
#
#       0s  Runs
# 37    15  7348
# 108    9  4037
# 131    5  3490
# 133   13  3428
# 138    0  3367
# ...   ..   ...
# 2440   0     0
# 2448   1     0
# 2462   1     0
# 2484   1     0
# 2487   2     0
#
# [335 rows x 16 columns]

# %%
first_players[["Team","Debute_Year"]].value_counts()
# Out:
# Team      Debute_Year
# BMUDA     2006           20
# AFG       2009           15
# NEPAL     2018           15
# KENYA     1996           15
# NZ        1973           14
# NAM       2003           14
# IRE       2006           13
# HKG       2004           13
# WI        1973           13
# SL        1975           13
# SCOT      1999           13
# SA        1991           13
# OMAN      2019           13
# INDIA     1974           13
# ZIM       1983           13
# EAf       1975           13
# CAN       1979           13
# NL        1996           12
# USA       2004           12
# PAK       1973           11
# ENG       1971           11
# UAE       1994           11
# BDESH     1986           11
# PNG       2014           10
# AUS       1971            8
# ENG/IRE   2006            2
# AUS/SA    1983            1
# USA/WI    1990            1
# AUS/NZ    2008            1
# ENG/SCOT  1997            1
# SA/USA    2010            1
# HKG/NZ    2015            1
# CAN/WI    1991            1
# NL/SA     2009            1
# 3)        2016            1
# ENG/PNG   2004            1
# 1)        2015            1
# Name: count, dtype: int64

# %%
data.sort_values(by='Runs', ascending=False).head(10)
# Out:
#         Player_Name   Team  Debute_Year  Retirment_Year  Span  Inns  \
# 0      SR Tendulkar  INDIA         1989            2012    23   452
# 1     KC Sangakkara     SL         2000            2015    15   380
# 2        RT Ponting    AUS         1995            2012    17   365
# 3     ST Jayasuriya     SL         1989            2011    22   433
# 4  DPMD Jayawardene     SL         1998            2015    17   418
# 5    Inzamam-ul-Haq    PAK         1991            2007    16   350
# 6           V Kohli  INDIA         2008            2019    11   233
# 7         JH Kallis     SA         1996            2014    18   314
# 8        SC Ganguly  INDIA         1992            2007    15   300
# 9          R Dravid  INDIA         1996            2011    15   318
#
#    HS_Not_Out   HS  NotOuts  Average  BallsFaced  StrikeRate  100s  50s  0s  \
# 0           1  200       41    44.83       21367       86.23    49   96  20
# 1           0  169       41    41.98       18048       78.86    25   93  15
# 2           0  164       39    42.03       17046       80.39    30   82  20
# 3           0  189       18    32.36       14725       91.20    28   68  34
# 4           0  144       39    33.37       16020       78.96    19   77  28
# 5           1  137       53    39.52       15812       74.24    10   83  20
# 6           0  183       39    59.84       12445       93.28    43   55  13
# 7           0  139       53    44.36       15885       72.89    17   86  17
# 8           0  183       23    41.02       15416       73.70    22   72  16
# 9           0  153       40    39.16       15284       71.24    12   83  13
#
#     Runs
# 0  18426
# 1  14234
# 2  13704
# 3  13430
# 4  12650
# 5  11739
# 6  11609
# 7  11579
# 8  11363
# 9  10889

# %%
# Group by 'Team' and calculate average 'Ave' and total 'Runs'
team_stats = data.groupby('Team').agg({'Average': 'mean', 'Runs': 'sum'}).reset_index()

# Find the team with the highest average
team_highest_average = team_stats.loc[team_stats['Average'].idxmax()]

# Find the team with the highest total runs
team_highest_runs = team_stats.loc[team_stats['Runs'].idxmax()]

# Display results
print("Team with the highest average:")
print(team_highest_average)

print("\nTeam with the highest total runs:")
print(team_highest_runs)
# Out:
# Team with the highest average:
# Team       HKG/NZ
# Average      40.0
# Runs          160
# Name: 16, dtype: object
#
# Team with the highest total runs:
# Team           INDIA
# Average    16.978341
# Runs          204716
# Name: 17, dtype: object

# %% [markdown]
# ## Introduction to NumPy: Array Creation and Operations

# %%
# Convert 'Runs' to numeric if needed
runs = pd.to_numeric(df['Runs'], errors='coerce').to_numpy()

# Total runs scored
total_runs = np.nansum(runs)  # Use np.nansum to ignore NaN values
print("Total Runs Scored:", total_runs)
# Out:
# Total Runs Scored: 1683824

# %%
# Ensure 'debuted_year' is numeric
data['debuted_year'] = pd.to_numeric(data['Debute_Year'], errors='coerce')

# Group by 'debuted_year' and count the number of players
data.groupby('debuted_year').size().reset_index(name='Total_Debutants')
# Out:
#     debuted_year  Total_Debutants
# 0           1971               19
# 1           1972               12
# 2           1973               49
# 3           1974               25
# 4           1975               49
# 5           1976               19
# 6           1977               26
# 7           1978               34
# 8           1979               35
# 9           1980               32
# 10          1981               16
# 11          1982               26
# 12          1983               48
# 13          1984               30
# 14          1985               26
# 15          1986               47
# 16          1987               29
# 17          1988               41
# 18          1989               19
# 19          1990               42
# 20          1991               25
# 21          1992               48
# 22          1993               33
# 23          1994               60
# 24          1995               45
# 25          1996               83
# 26          1997               53
# 27          1998               50
# 28          1999               62
# 29          2000               46
# 30          2001               56
# 31          2002               60
# 32          2003               80
# 33          2004               86
# 34          2005               37
# 35          2006              121
# 36          2007               66
# 37          2008               98
# 38          2009               82
# 39          2010               77
# 40          2011               68
# 41          2012               38
# 42          2013               69
# 43          2014               80
# 44          2015               58
# 45          2016               66
# 46          2017               59
# 47          2018               69
# 48          2019              101

# %%
# Convert 'Ave' to numeric if needed
averages = pd.to_numeric(df['Ave'], errors='coerce').to_numpy()

# Mean and median
mean_ave = np.nanmean(averages)  # Average ignoring NaN values
median_ave = np.nanmedian(averages)  # Median ignoring NaN values

print("Mean Average:", mean_ave)
print("Median Average:", median_ave)
# Out:
# Mean Average: 17.330384
# Median Average: 15.33

# %%
# Sort and select the top 5 run-scorers
top_5_runs = np.sort(runs)[-5:][::-1]
print("Top 5 Run Scores:", top_5_runs)
# Out:
# Top 5 Run Scores: [18426 14234 13704 13430 12650]

# %%
# Calculate the mean of runs
average_runs = np.nanmean(runs)

# Find players with above-average runs
above_average = runs > average_runs

# Use the boolean mask to extract player names
players_above_average = df['Player'].to_numpy()[above_average]
print("Players with Above-Average Runs:")
print(players_above_average)
# Out:
# Players with Above-Average Runs:
# ['SR Tendulkar (INDIA)' 'KC Sangakkara (Asia/ICC/SL)'
#  'RT Ponting (AUS/ICC)' 'ST Jayasuriya (Asia/SL)'
#  'DPMD Jayawardene (Asia/SL)' 'Inzamam-ul-Haq (Asia/PAK)'
#  'V Kohli (INDIA)' 'JH Kallis (Afr/ICC/SA)' 'SC Ganguly (Asia/INDIA)'
#  'R Dravid (Asia/ICC/INDIA)' 'MS Dhoni (Asia/INDIA)' 'CH Gayle (ICC/WI)'
#  'BC Lara (ICC/WI)' 'TM Dilshan (SL)' 'Mohammad Yousuf (Asia/PAK)'
#  'AC Gilchrist (AUS/ICC)' 'AB de Villiers (Afr/SA)' 'M Azharuddin (INDIA)'
#  'PA de Silva (SL)' 'RG Sharma (INDIA)' 'Saeed Anwar (PAK)'
#  'S Chanderpaul (WI)' 'Yuvraj Singh (Asia/INDIA)' 'DL Haynes (WI)'
#  'MS Atapattu (SL)' 'ME Waugh (AUS)' 'LRPL Taylor (NZ)'
#  'V Sehwag (Asia/ICC/INDIA)' 'HM Amla (SA)' 'HH Gibbs (SA)'
#  'Shahid Afridi (Asia/ICC/PAK)' 'SP Fleming (ICC/NZ)' 'MJ Clarke (AUS)'
#  'SR Waugh (AUS)' 'Shoaib Malik (PAK)' 'A Ranatunga (SL)'
#  'Javed Miandad (PAK)' 'EJG Morgan (ENG/IRE)' 'Younis Khan (PAK)'
#  'Saleem Malik (PAK)' 'NJ Astle (NZ)' 'GC Smith (Afr/SA)'
#  'WU Tharanga (Asia/SL)' 'MG Bevan (AUS)' 'Tamim Iqbal (BDESH)'
#  'G Kirsten (SA)' 'A Flower (ZIM)' 'IVA Richards (WI)' 'MJ Guptill (NZ)'
#  'Mohammad Hafeez (PAK)' 'GW Flower (ZIM)' 'Ijaz Ahmed (PAK)'
#  'AR Border (AUS)' 'Shakib Al Hasan (BDESH)' 'BRM Taylor (ZIM)'
#  'RB Richardson (WI)' 'ML Hayden (AUS/ICC)' 'KS Williamson (NZ)'
#  'Mushfiqur Rahim (BDESH)' 'BB McCullum (NZ)' 'DM Jones (AUS)'
#  'DC Boon (AUS)' 'JN Rhodes (SA)' 'JE Root (ENG)' 'Rameez Raja (PAK)'
#  'AD Mathews (SL)' 'RR Sarwan (WI)' 'CL Hooper (WI)' 'SR Watson (AUS)'
#  'H Masakadza (ZIM)' 'SK Raina (INDIA)' 'MN Samuels (WI)' 'WJ Cronje (SA)'
#  'S Dhawan (INDIA)' 'F du Plessis (SA)' 'MEK Hussey (AUS)' 'IR Bell (ENG)'
#  'A Jadeja (INDIA)' 'DR Martyn (AUS)' 'G Gambhir (INDIA)'
#  'ADR Campbell (ZIM)' 'RS Mahanama (SL)' 'CG Greenidge (WI)'
#  'Misbah-ul-Haq (PAK)' 'JP Duminy (SA)' 'PD Collingwood (ENG)'
#  'A Symonds (AUS)' 'Abdul Razzaq (Asia/PAK)' 'DA Warner (AUS)'
#  'CL Cairns (ICC/NZ)' 'Q de Kock (SA)' 'Aamer Sohail (PAK)'
#  'CD McMillan (NZ)' 'MD Crowe (NZ)' 'MV Boucher (Afr/SA)'
#  'AJ Stewart (ENG)' 'AJ Finch (AUS)' 'SB Styris (NZ)'
#  'KP Pietersen (ENG/ICC)' 'NS Sidhu (INDIA)' 'CZ Harris (NZ)'
#  'GR Marsh (AUS)' 'E Chigumbura (Afr/ZIM)' 'ME Trescothick (ENG)'
#  'GA Gooch (ENG)' 'AJ Strauss (ENG)' 'K Srikkanth (INDIA)'
#  'PR Stirling (IRE)' 'WTS Porterfield (IRE)' 'AJ Lamb (ENG)'
#  'Mahmudullah (BDESH)' 'RP Arnold (SL)' 'AP Gurusinha (SL)'
#  'JG Wright (NZ)' 'DJ Cullinan (SA)' 'GA Hick (ENG)' 'JC Buttler (ENG)'
#  'SPD Smith (AUS)' 'HP Tillakaratne (SL)' 'N Kapil Dev (INDIA)'
#  'Wasim Akram (PAK)' 'SC Williams (ZIM)' 'RS Kaluwitharana (SL)'
#  'Imran Khan (PAK)' 'PV Simmons (WI)' 'NV Knight (ENG)'
#  'LD Chandimal (SL)' 'L Klusener (SA)' 'SM Pollock (Afr/ICC/SA)'
#  'MA Taylor (AUS)' 'DB Vengsarkar (INDIA)' "KJ O'Brien (IRE)"
#  'Mohammad Ashraful (Asia/BDESH)' 'SO Tikolo (Afr/KENYA)'
#  'HH Dippenaar (Afr/SA)' 'A Flintoff (ENG/ICC)' 'T Taibu (Afr/ZIM)'
#  'JJ Roy (ENG)' 'KC Wessels (AUS/SA)' 'Babar Azam (PAK)' 'AC Parore (NZ)'
#  'Moin Khan (PAK)' 'Kamran Akmal (PAK)' 'AN Cook (ENG)'
#  'HDRL Thirimanne (SL)' 'Umar Akmal (PAK)' 'DI Gower (ENG)'
#  'KR Rutherford (NZ)' 'BJ Haddin (AUS)' 'RJ Shastri (INDIA)'
#  'SM Gavaskar (INDIA)' 'DS Lehmann (AUS)' 'DA Miller (SA)'
#  'GJ Bailey (AUS)' 'SD Hope (WI)' 'V Sibanda (Afr/ZIM)' 'DJ Bravo (WI)'
#  'AM Rahane (INDIA)' 'HH Streak (Afr/ZIM)' 'WW Hinds (WI)'
#  'GJ Maxwell (AUS)' 'JM Bairstow (ENG)' 'DM Bravo (WI)' 'IJL Trott (ENG)'
#  'AL Logie (WI)' 'AH Jones (NZ)' 'Mohammad Nabi (AFG)' 'SE Marsh (AUS)'
#  'M Kaif (INDIA)' 'SV Carlisle (ZIM)' 'MDKJ Perera (SL)'
#  'Mohammad Shahzad (AFG)' 'Salman Butt (PAK)' 'RG Twose (NZ)'
#  'GJ Whittall (ZIM)' 'RS Bopara (ENG)' 'BA Stokes (ENG)'
#  'Sikandar Raza (ZIM)' 'Mudassar Nazar (PAK)' 'EC Joyce (ENG/IRE)'
#  'Ahmed Shehzad (PAK)' "NJ O'Brien (IRE)" 'Zaheer Abbas (PAK)'
#  'CR Ervine (ZIM)' 'AC Hudson (SA)' 'TWM Latham (NZ)' 'VG Kambli (INDIA)'
#  'Imrul Kayes (BDESH)' 'JDP Oram (NZ)' 'TM Odoyo (Afr/KENYA)'
#  'AD Hales (ENG)' 'RA Smith (ENG)' 'L Vincent (NZ)' 'KJ Coetzer (SCOT)'
#  'KA Pollard (WI)' 'CJ Chibhabha (ZIM)' 'GP Thorpe (ENG)'
#  'Rahmat Shah (AFG)' 'Asghar Afghan (AFG)' 'VVS Laxman (INDIA)'
#  'RR Singh (INDIA)' 'N Hussain (ENG)' 'GS Chappell (AUS)'
#  'Sarfaraz Ahmed (PAK)' 'SL Campbell (WI)' 'DL Vettori (ICC/NZ)'
#  'S Matsikenyeri (ZIM)' 'GM Wood (AUS)' 'NLTC Perera (SL)'
#  'MJ Greatbatch (NZ)' 'JC Adams (WI)' 'Shahriar Nafees (BDESH)'
#  'D Ramdin (WI)' 'RA Jadeja (INDIA)' 'CS MacLeod (SCOT)'
#  'Habibul Bashar (BDESH)' 'IT Botham (ENG)' 'MW Gatting (ENG)'
#  'NH Fairbrother (ENG)' 'RL Powell (WI)' 'CL White (AUS)'
#  'GC Wilson (IRE)' 'CO Obuya (KENYA)' 'Yasir Hameed (PAK)'
#  'WPUJC Vaas (Asia/SL)' 'KO Otieno (KENYA)' 'SV Manjrekar (INDIA)'
#  'MP Vaughan (ENG)' 'CH Lloyd (WI)' 'GD Elliott (NZ)' 'BKG Mendis (SL)'
#  'KJ Hughes (AUS)' 'A Bagai (CAN)' 'Fakhar Zaman (PAK)' 'LMP Simmons (WI)'
#  'Aftab Ahmed (BDESH)' 'PJL Dujon (WI)' 'M Amarnath (INDIA)'
#  'KLT Arthurton (WI)' 'Imran Nazir (PAK)' 'RD Berrington (SCOT)'
#  'Mohsin Khan (PAK)' 'JV Coney (NZ)' 'DJG Sammy (WI)' 'RD Jacobs (WI)'
#  'M Prabhakar (INDIA)' 'Azhar Ali (PAK)' 'OA Shah (ENG)'
#  'MW Goodwin (ZIM)' 'Khaled Mashud (BDESH)' 'BA Edgar (NZ)'
#  'A Balbirnie (IRE)' 'Samiullah Shinwari (AFG)' 'JO Holder (WI)'
#  'DJ Hussey (AUS)' 'MA Atherton (ENG)' 'Mashrafe Mortaza (Asia/BDESH)'
#  'MS Wade (AUS)' 'MM Ali (ENG)' 'IA Healy (AUS)' 'KD Karthik (INDIA)'
#  'Sir RJ Hadlee (NZ)' 'Soumya Sarkar (BDESH)' 'Imam-ul-Haq (PAK)'
#  'Imran Farhat (PAK)' 'CB Wishart (ZIM)' 'Rashid Latif (PAK)'
#  'DA Gunawardene (SL)' 'AT Rayudu (INDIA)' 'ND McKenzie (SA)'
#  'NC Johnson (ZIM)' 'BA Young (NZ)' 'UDU Chandana (SL)'
#  'CK Kapugedera (SL)' 'Haris Sohail (PAK)' 'GM Turner (NZ)'
#  'LPC Silva (SL)' 'Najibullah Zadran (AFG)' 'SC Williams (WI)'
#  'Saleem Elahi (PAK)' 'RL Dias (SL)' 'N Dickwella (SL)' 'DR Smith (WI)'
#  'UT Khawaja (AUS)' 'IK Pathan (INDIA)' 'RN ten Doeschate (NL)'
#  'DL Houghton (ZIM)' 'LRD Mendis (SL)' 'Azhar Mahmood (PAK)'
#  'RS Morton (WI)' 'JJ Crowe (NZ)' 'JM Kemp (Afr/SA)' 'RD Shah (KENYA)'
#  'MA Ouma (KENYA)' 'HJH Marshall (NZ)' 'DD Ebrahim (ZIM)' 'MR Marsh (AUS)'
#  'Nasir Jamshed (PAK)' 'SO Hetmyer (WI)' 'HA Gomes (WI)' 'N Boje (Afr/SA)'
#  'MO Odumbe (KENYA)' 'P Utseya (ZIM)' 'E Lewis (WI)' 'L Ronchi (AUS/NZ)'
#  'GP Howarth (NZ)' 'JD Ryder (NZ)' 'BC Broad (ENG)' 'DO Obuya (KENYA)'
#  'KM Jadhav (INDIA)' 'Asad Shafiq (PAK)' 'PG Fulton (NZ)'
#  'Sabbir Rahman (BDESH)' 'KMDN Kulasekara (SL)' 'JR Hopes (AUS)'
#  'SM Katich (AUS)' 'Javed Omar (BDESH)' 'Raqibul Hasan (BDESH)'
#  'AA Obanda (KENYA)' 'MS Sinclair (NZ)' 'PN Kirsten (SA)' 'J Charles (WI)'
#  'MJ Prior (ENG)' 'Nasir Hossain (BDESH)' 'TM Head (AUS)'
#  'NR Mongia (INDIA)' 'C Munro (NZ)' 'JEC Franklin (NZ)'
#  'AB Agarkar (INDIA)' 'Shoaib Mohammad (PAK)' 'Basit Ali (PAK)'
#  'MN Waller (ZIM)' 'MD Gunathilaka (SL)' 'JDS Neesham (NZ)'
#  "SP O'Donnell (AUS)" 'RR Rossouw (SA)' 'Harbhajan Singh (Asia/INDIA)'
#  'SG Law (AUS)' 'Alok Kapali (BDESH)' 'GM Hamilton (SCOT)'
#  'D Mongia (INDIA)' 'RW Marsh (AUS)' 'HDPK Dharmasena (SL)'
#  'Shaiman Anwar (UAE)' 'Noor Ali Zadran (AFG)' 'TM Moody (AUS)'
#  'Junaid Siddique (BDESH)' 'Mohammad Rafique (Asia/BDESH)'
#  'CR Woakes (ENG)' 'B Lee (AUS)' 'JA Rudolph (Afr/SA)'
#  'Nawroz Mangal (AFG)' 'MH Cross (SCOT)' 'T Mishra (KENYA)'
#  'HM Nicholls (NZ)' 'PL Mommsen (SCOT)' 'MF Maharoof (SL)'
#  'CJ Anderson (NZ)' 'HS Modi (KENYA)' 'ES Szwarczynski (NL)'
#  'VS Solanki (ENG)' 'B Zuiderent (NL)' 'PA Strang (ZIM)' 'G Boycott (ENG)'
#  'F Behardien (SA)' 'NL McCullum (NZ)' 'Asif Mujtaba (PAK)'
#  'DW Randall (ENG)' 'Hashmatullah Shahidi (AFG)' 'DS Smith (WI)'
#  'JK Kamande (KENYA)' 'IDS Smith (NZ)' 'C Kieswetter (ENG)'
#  'Anamul Haque (BDESH)' 'MP Stoinis (AUS)' 'KD Mills (NZ)' 'JM How (NZ)'
#  'Gulbadin Naib (AFG)' 'AD Russell (WI)' 'JP Faulkner (AUS)'
#  'DSBP Kuruppu (SL)' 'AG Prince (Afr/SA)' 'SK Warne (AUS/ICC)'
#  'SM Patil (INDIA)' 'KOA Powell (WI)' 'Rajin Saleh (BDESH)'
#  'PW Borren (NL)' 'NFI McCallum (SCOT)' 'Khaled Mahmud (BDESH)'
#  'BL Cairns (NZ)' 'MJ Slater (AUS)' 'MJ Horne (NZ)' 'Akram Khan (BDESH)'
#  'TLW Cooper (NL)' 'Javed Ahmadi (AFG)' 'Naeem Islam (BDESH)'
#  'DF Watts (SCOT)' 'Waqar Younis (PAK)' 'Fawad Alam (PAK)'
#  'SA Thomson (NZ)' 'JF Mooney (IRE)' 'GM Ritchie (AUS)'
#  'HH Pandya (INDIA)' 'RR Watson (SCOT)' 'MD Marshall (WI)' 'SF Mire (ZIM)'
#  'Imad Wasim (PAK)' 'MG Johnson (AUS)' 'RS Madugalle (SL)' 'NT Broom (NZ)'
#  'A Kumble (Asia/INDIA)' 'CM Spearman (NZ)' 'RV Uthappa (INDIA)'
#  'W Barresi (NL)' 'AN Kervezee (NL)' 'S Dhaniram (CAN)' 'AJ Hall (SA)'
#  'Rashid Khan (AFG)' 'MJ Santner (NZ)' 'TD Paine (AUS)' 'KL Rahul (INDIA)'
#  'JWA Taylor (ENG)' 'J Srinath (INDIA)' 'Yashpal Sharma (INDIA)'
#  'TT Bresnan (ENG)' 'SHT Kandamby (SL)' 'AC Voges (AUS)'
#  'DJ Richardson (SA)' 'MA Vermeulen (ZIM)' 'HK Badani (INDIA)'
#  'GO Jones (ENG/PNG)' 'TT Samaraweera (SL)' 'SB Smith (AUS)'
#  'DL Amiss (ENG)' 'RA Harper (WI)' 'WB Phillips (AUS)' 'CWJ Athey (ENG)'
#  'RS Kalpage (SL)' 'MAR Samarasekera (SL)' 'D Ganga (WI)' 'CA Ingram (SA)'
#  'BM McMillan (SA)' 'CK Coventry (ZIM)' 'Anshuman Rath (HKG)'
#  'PJ Moor (ZIM)' 'DW Hookes (AUS)' 'PJ Hughes (AUS)'
#  'AI Kallicharran (WI)' 'JR Ratnayeke (SL)' 'GN Yallop (AUS)'
#  'AC Waller (ZIM)' 'DM de Silva (SL)' 'Sharjeel Khan (PAK)'
#  'YK Pathan (INDIA)' 'AT Carey (AUS)' 'JM Davison (CAN)'
#  'Aminul Islam (BDESH)' 'Z Khan (Asia/INDIA)' 'GB Hogg (AUS)'
#  'Majid Khan (PAK)' 'S Wettimuny (SL)' 'Babar Hayat (HKG)'
#  'R Lamba (INDIA)' 'IH Romaine (BMUDA)' 'JA Morkel (Afr/SA)'
#  'Wasim Raja (PAK)' 'Abdur Razzak (BDESH)' 'AR White (IRE)'
#  'Liton Das (BDESH)' 'Saleem Yousuf (PAK)' 'CN Evans (ZIM)'
#  'Rizwan Cheema (CAN)' 'KWR Fletcher (ENG)' 'J Dyson (AUS)'
#  'AR Cusack (IRE)' 'AG Cremer (ZIM)' 'G Fowler (ENG)' 'DT Johnston (IRE)'
#  'Manzoor Elahi (PAK)' 'AM Samad (CAN)' 'A Vala (PNG)' 'PA Patel (INDIA)'
#  'Sohaib Maqsood (PAK)' 'MW Machan (SCOT)' 'CJ Nevin (NZ)' 'N Pooran (WI)'
#  'CJ Tavare (ENG)' 'TP Ura (PNG)' 'MA Ealham (ENG)' 'IJ Harvey (AUS)'
#  'Muhammad Usman (UAE)' 'Saqlain Mushtaq (PAK)' 'LJ Wright (ENG)'
#  'Mohammad Rizwan (PAK)' 'J Mubarak (SL)' 'PA Wallace (WI)'
#  'SM Ervine (ZIM)' 'PL Symcox (SA)' 'Rameez Shahzad (UAE)'
#  'PAJ DeFreitas (ENG)' 'N Deonarine (WI)' 'Wahab Riaz (PAK)'
#  'JR Murray (WI)' 'TG Southee (NZ)' 'R Ashwin (INDIA)'
#  'Nizakat Khan (HKG)' 'M Muralitharan (Asia/ICC/SL)']

# %%
# Extract 'debuted_year' column as NumPy array
debut_years = data['Debute_Year'].to_numpy()

# Get unique years and their counts
unique_years, debutants_count = np.unique(debut_years, return_counts=True)

# Combine into a structured array
debutants_data = np.array(list(zip(unique_years, debutants_count)), dtype=[('Year', 'int'), ('Debutants', 'int')])

# Display the debutants data
print("Total Debutants Per Year:")
print(debutants_data)
# Out:
# Total Debutants Per Year:
# [(1971,  19) (1972,  12) (1973,  49) (1974,  25) (1975,  49) (1976,  19)
#  (1977,  26) (1978,  34) (1979,  35) (1980,  32) (1981,  16) (1982,  26)
#  (1983,  48) (1984,  30) (1985,  26) (1986,  47) (1987,  29) (1988,  41)
#  (1989,  19) (1990,  42) (1991,  25) (1992,  48) (1993,  33) (1994,  60)
#  (1995,  45) (1996,  83) (1997,  53) (1998,  50) (1999,  62) (2000,  46)
#  (2001,  56) (2002,  60) (2003,  80) (2004,  86) (2005,  37) (2006, 121)
#  (2007,  66) (2008,  98) (2009,  82) (2010,  77) (2011,  68) (2012,  38)
#  (2013,  69) (2014,  80) (2015,  58) (2016,  66) (2017,  59) (2018,  69)
#  (2019, 101)]

# %%
# Normalize runs
normalized_runs = (runs - np.nanmin(runs)) / (np.nanmax(runs) - np.nanmin(runs))
print("Normalized Runs:")
print(normalized_runs)
# Out:
# Normalized Runs:
# [1.         0.77249539 0.74373168 ... 0.         0.         0.        ]

# %%
data
# Out:
#            Player_Name   Team  Debute_Year  Retirment_Year  Span  Inns  \
# 0         SR Tendulkar  INDIA         1989            2012    23   452
# 1        KC Sangakkara     SL         2000            2015    15   380
# 2           RT Ponting    AUS         1995            2012    17   365
# 3        ST Jayasuriya     SL         1989            2011    22   433
# 4     DPMD Jayawardene     SL         1998            2015    17   418
# ...                ...    ...          ...             ...   ...   ...
# 2495         ZS Ansari    ENG         2015            2015     0     0
# 2496      Ariful Haque  BDESH         2018            2018     0     0
# 2497      Ashfaq Ahmed    PAK         1994            1994     0     0
# 2498         MD Bailey     NZ         1998            1998     0     0
# 2499          GR Beard    AUS         1981            1981     0     0
#
#       HS_Not_Out   HS  NotOuts  Average  BallsFaced  StrikeRate  100s  50s  \
# 0              1  200       41    44.83       21367       86.23    49   96
# 1              0  169       41    41.98       18048       78.86    25   93
# 2              0  164       39    42.03       17046       80.39    30   82
# 3              0  189       18    32.36       14725       91.20    28   68
# 4              0  144       39    33.37       16020       78.96    19   77
# ...          ...  ...      ...      ...         ...         ...   ...  ...
# 2495           0    0        0     0.00           0        0.00     0    0
# 2496           0    0        0     0.00           0        0.00     0    0
# 2497           0    0        0     0.00           0        0.00     0    0
# 2498           0    0        0     0.00           0        0.00     0    0
# 2499           0    0        0     0.00           0        0.00     0    0
#
#       0s   Runs  debuted_year
# 0     20  18426          1989
# 1     15  14234          2000
# 2     20  13704          1995
# 3     34  13430          1989
# 4     28  12650          1998
# ...   ..    ...           ...
# 2495   0      0          2015
# 2496   0      0          2018
# 2497   0      0          1994
# 2498   0      0          1998
# 2499   0      0          1981
#
# [2500 rows x 17 columns]

# %%
# Using Pandas
import timeit
start_pandas = timeit.timeit()
data['Runs'].sum()
end_pandas = timeit.timeit()
print("Pandas Execution Time:", end_pandas - start_pandas)

# Using NumPy
start_numpy = timeit.timeit()
runs_array = data['Runs'].to_numpy()
np.nansum(runs_array)
end_numpy = timeit.timeit()
print("NumPy Execution Time:", end_numpy - start_numpy)
# Out:
# Pandas Execution Time: -0.00011150000500492752
# NumPy Execution Time: 0.00034080000477842987

# %% [markdown]
#  ### Summary of Differences
#  | Feature               | Pandas                           | NumPy                        |
#  |------------------------|-----------------------------------|------------------------------|
#  | **Data Structure**     | DataFrame (tabular), Series      | Multidimensional arrays      |
#  | **Ease of Use**        | High (especially for tabular data)| Moderate (focused on arrays) |
#  | **Performance**        | Slower than NumPy for numbers    | Faster for numerical operations |
#  | **Missing Data**       | Handles `NaN` natively           | Requires `np.nan_to_num` or `np.isnan` |
#  | **Grouped Operations** | Easy with `groupby`              | Requires additional logic    |
#
# #### NumPy is optimal for raw numerical operations, while Pandas excels in handling structured, tabular data.

# %%
# Save the DataFrame to a CSV file
data.to_csv('cricket_data.csv', index=False)

print("Data saved to 'cricket_data.csv'")
# Out:
# Data saved to 'cricket_data.csv'
